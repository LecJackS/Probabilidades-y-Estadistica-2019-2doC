# %%
?replicate

# %%
replicate(3, rnorm(5), simplify = "data.frame")[[1]]
# Out:
# [1] -0.5196472

# %% [markdown]
# # Gamma $(1, \frac 1 2) \equiv$  Exp $(\frac 1 2)$
#
# Una exponencial de parámetro $\lambda = \frac 1 2$ tiene la misma distribución que una Gamma $(\alpha=1, \lambda= \frac 1 2)$
#
# > Gamma$(\alpha, \lambda)$:
# > $$\large f_X(x) = \frac {\lambda^\alpha}{\Gamma(\alpha)} x^{\alpha-1} e^{-\lambda x}$$
#
# Si $\alpha = 1$:
#
# * $\Gamma(\alpha) = 1$
#
# > Gamma$(1, \lambda) \equiv$  Exp $(\lambda)$:
# > $$\large f_X(x) = \lambda e^{-\lambda x}$$

# %%
grilla <- seq(0, 15, 0.1)
# Gamma
plot(dgamma(grilla, 1, 1/2), pch=1, col="blue")

# Exponencial
points(dexp(grilla, 1/2), pch=1, cex=0.5, col="red")

# Chi Cuadrado
points(dchisq(grilla, df=2),cex=1.5, col="black")
# Out:
# plot without title

# %%
grilla <- seq(0, 20, 0.1)
par(mfrow=c(3,3))
# Gamma
plot(dgamma(grilla, 1, 1/2), pch=1, col="blue")
# Gamma
plot(dgamma(grilla, 2, 1/2), pch=1, col="blue")
# Gamma
plot(dgamma(grilla, 3, 1/2), pch=1, col="blue")
# Gamma
plot(dgamma(grilla, 4, 1/2), pch=1, col="blue")
# Gamma
plot(dgamma(grilla, 5, 1/2), pch=1, col="blue")
# Gamma
plot(dgamma(grilla, 6, 1/2), pch=1, col="blue")
# Gamma
plot(dgamma(grilla, 7, 1/2), pch=1, col="blue")
# Gamma
plot(dgamma(grilla, 8, 1/2), pch=1, col="blue")
# Gamma
plot(dgamma(grilla, 9, 1/2), pch=1, col="blue")
# Out:
# plot without title

# %%
grilla <- seq(0, 200, 0.1)
par(mfrow=c(3,2))
# Gamma
plot(grilla, dgamma(grilla, 10, 1/2), pch=1, col="blue")
# Gamma
plot(grilla, dgamma(grilla, 20, 1/2), pch=1, col="blue")
# Gamma
plot(grilla, dgamma(grilla, 30, 1/2), pch=1, col="blue")
# Gamma
plot(grilla, dgamma(grilla, 40, 1/2), pch=1, col="blue")
# Gamma
plot(grilla, dgamma(grilla, 50, 1/2), pch=1, col="blue")
# Gamma
plot(grilla, dgamma(grilla, 100, 1/2), pch=1, col="blue")
# Out:
# plot without title

# %%
grilla <- seq(97000, 103000, 1)
# Gamma
plot(grilla, dgamma(grilla, 50000, 1/2), pch=1, col="blue")
# Out:
# plot without title

# %%
grid <- seq(0,10,0.1)
data <- dchisq(grid, df=1)
plot(grid, data, pch=1, type="o")

points(grid, dchisq(grid, df=2), col="lightblue", pch=19, type="o")

points(grid, dchisq(grid, df=3), col="steelblue", pch=19, type="o")

points(grid, dchisq(grid, df=4), col="blue", pch=19, type="o")

points(grid, dchisq(grid, df=5), col="orange", pch=19, type="o")

points(grid, dchisq(grid, df=10), col="red", pch=19, type="o")
# Out:
# Warning message in plot.xy(xy.coords(x, y), type = type, ...):
# “"label" is not a graphical parameter”
# plot without title

# %%
grid <- seq(0, 30, 0.1)
plot(grid, dchisq(grid, df=10), col="red", pch=19, type="o", main="df = 10")
# Out:
# Plot with title “df = 10”

# %%
grid <- seq(0, 30, 0.1)
df <- 1
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2
par(mfrow=c(2,2))
plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 1", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 2
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 2", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 3
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 3", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 4
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 4", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 5
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 5", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 10
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 10", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 20
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 20", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 30
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 30", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 50
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 50", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 100
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 100", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 200
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 200", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")

df <- 500
data <- rchisq(1e+5, df=df)
esperanza <- df/2 * 2
varianza <- df/2 * 2**2

plot(sort((data-esperanza)/sqrt(varianza)), col="red", pch=19, type="o", main="sort( data )")
hist(((data-esperanza)/sqrt(varianza)), col="steelblue", freq=FALSE, main="df = 500", breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")
# Out:
# Plot with title “df = 2”
# Plot with title “df = 4”
# Plot with title “df = 10”
# Plot with title “df = 30”
# Plot with title “df = 100”
# Plot with title “df = 500”

# %%
hist(((data-esperanza)/sqrt(varianza)),
     col="steelblue",
     freq=FALSE, main="df = 30",
     breaks=floor(sqrt(1e+5)),
    border=NA)
lines(seq(-2,2,0.1), dnorm(seq(-2,2,0.1)), col="orange")
# Out:
# Plot with title “df = 30”
