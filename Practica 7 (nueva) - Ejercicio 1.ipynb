# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Con datos del enunciado

# %%
data_del_pdf <- c(76.93, 76.88, 77.07, 76.68, 76.39, 75.09, 77.67, 76.88, 78.15, 76.50, 77.16, 76.42)

# %%
data
# Out:
#  [1] 76.93 76.88 77.07 76.68 76.39 75.09 77.67 76.88 78.15 76.50 77.16 76.42

# %%
# a)
mean(data)
# Out:
# [1] 76.81833

# %%
# b)
median(data)
# Out:
# [1] 76.88

# %%
# c) Pide proporción de de valores por debajo o iguales a 76.5
sort(data)
# Out:
#  [1] 75.09 76.39 76.42 76.50 76.68 76.88 76.88 76.93 77.07 77.16 77.67 78.15

# %% [markdown]
# Que como podemos contar es 4/12 = 1/3

# %%
length(data[data <= 76.5]) / length(data)
# Out:
# [1] 0.3333333

# %% [markdown]
# ### Con datos generados en el sitio:

# %%
data_n5 <- read.csv("./data/practica7/datos_Practica7_ej1_n_5.csv")
data_n50 <- read.csv("./data/practica7/datos_Practica7_ej1_n_50.csv")
data_n100 <- read.csv("./data/practica7/datos_Practica7_ej1_n_100.csv")

# %%
# a) 
mean(data_n5$carbohidratos)
mean(data_n50$carbohidratos)
mean(data_n100$carbohidratos)
# Out:
# [1] 76.73075
# [1] 76.7233
# [1] 76.77723

# %%
# b)
median(data_n5$carbohidratos)
median(data_n50$carbohidratos)
median(data_n100$carbohidratos)
# Out:
# [1] 76.9217
# [1] 76.77222
# [1] 76.84233

# %%
#c) Proporcion de valores <= 76.5
length(data_n5$carbohidratos[data_n5$carbohidratos <= 76.5]) / length(data_n5$carbohidratos)
length(data_n50$carbohidratos[data_n50$carbohidratos <= 76.5]) / length(data_n50$carbohidratos)
length(data_n100$carbohidratos[data_n100$carbohidratos <= 76.5]) / length(data_n100$carbohidratos)
# Out:
# [1] 0.2
# [1] 0.26
# [1] 0.3

# %% [markdown]
# # Plots

# %%
par(mfrow=c(2,2))
plot(data_n100$carbohidratos, col="lightblue", cex=1.5)
points(data_n50$carbohidratos, col="red", cex=1.25)
points(data_n5$carbohidratos, col="blue")

hist(data_n100$carbohidratos, col="lightblue")

boxplot(data_n100$carbohidratos, col="lightblue")

qqnorm(data_n100$carbohidratos, col="black", cex=0.5)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
par(mfrow=c(2,2))
hist(data_n100$carbohidratos, col="lightblue")
hist(data_n50$carbohidratos, col="red")
hist(data_n5$carbohidratos, col="blue")
# Out:
# Plot with title “Histogram of data_n5$carbohidratos”

# %%
boxplot(data_n100$carbohidratos,
        data_n50$carbohidratos,
        data_n5$carbohidratos , col=c("lightblue","red","blue"))
# Out:
# plot without title
